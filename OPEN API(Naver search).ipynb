# %% [markdown]
# From [Suanlab](https://www.youtube.com/channel/UCFfALXX0DOx7zv6VeR5U_Bg)
# # 네이버 검색 API 활용하기

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re # regular expression 정규식 표현으로 태그 없애는것 

client_id = "Cw73NT3Tcw6bE7ZPbhEO"
client_secret = "cCSEN3USLB"

# %%
#url 관련변수 설정
#encText = urllib.parse.quote("컴퓨터") #utf8로 바꿔줌
query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display =100
start = 1
end = 1000

web_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
                            
    url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
           + "&display=" + str(display) \
           + "&start=" + str(start_index)
                  
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode() 
    if(rescode==200): #200은 성공한것
        response_body = response.read()
        response_dict =json.loads(response_body.decode('utf-8'))      
        #json title link description parse
        items = response_dict['items']
        for item_index in range(0, len(items)):
          remove_tag = re.compile('<.*?>')
          title =re.sub(remove_tag, '', items[item_index]['title'])
          link = items[item_index]['link']
          description = re.sub(remove_tag, '', items[item_index]['description'])
          web_df.loc[idx] = [title, link, description]
          idx += 1
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색 질의:  아이폰
#                                              Title  ...                                        Description
# 0                              iPhone - Apple (KR)  ...  세상에서 가장 강력한 개인용 기기, iPhone을 만나볼까요? iPhone 12 P...
# 1                                    iPhone - 나무위키  ...  아이폰은(는) 여기로 연결됩니다. 동일한 명칭을 가지는 일본의 인터폰 회사에 대한 ...
# 2                                   iPhone - Apple  ...  iPhone 12 and iPhone 12 mini Blast past fast. ...
# 3                   아이폰에서 컴퓨터로 사진 옮기는 방법 - wikiHow  ...  이 위키하우 글을 읽고 아이폰에서 윈도우나 맥 컴퓨터로 사진을 옮기는 방법에 대해 ...
# 4                                  iPhone X - 나무위키  ...  이 문서를 편집한 기록이 있어야 편집 가능한 문서입니다. [ 펼치기 · 접기 ] i...
# ..                                             ...  ...                                                ...
# 161  시장 점유율은 '갤럭시·샤오미·아이폰' 순...보안 성능 순위는? - 오피니언뉴스  ...  아이폰의 경우 미국 연방수사국(FBI)과 우리 검찰, 경찰 등 수사기관은 아이폰 잠...
# 162                                전 상품 – CASETiFY  ...  소중한 아이폰 12 프로를 보호하세요. 약 2미터 높이의 낙하로부터 안전한 강한 보...
# 163                             iPhone - Apple（日本）  ...  iPhone 12とiPhone 12 mini 早い話、速いです。 下取りがない場合は、2...
# 164                            iPhone - Apple (UK)  ...  iPhone 12 and iPhone 12 mini Blast past fast. ...
# 165                             daewoo-elecsvc.com  ...  daewoo-elecsvc.com Privacy Policy | 2021 Copyr...
#
# [166 rows x 3 columns]

# %% [markdown]
# ## 네이버 지식인 API

# %%
#url 관련변수 설정
#encText = urllib.parse.quote("컴퓨터") #utf8로 바꿔줌
query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display =100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
                            
    url = "https://openapi.naver.com/v1/search/kin?query=" + query \
           + "&display=" + str(display) \
           + "&start=" + str(start_index) \
           + "&sort=" + sort
                  
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode() 
    if(rescode==200): #200은 성공한것
        response_body = response.read()
        response_dict =json.loads(response_body.decode('utf-8'))      
        #json title link description parse
        items = response_dict['items']
        for item_index in range(0, len(items)):
          remove_tag = re.compile('<.*?>')
          title =re.sub(remove_tag, '', items[item_index]['title'])
          link = items[item_index]['link']
          description = re.sub(remove_tag, '', items[item_index]['description'])
          kin_df.loc[idx] = [title, link, description]
          idx += 1
    else:
        print("Error Code:" + rescode)
kin_df
# Out:
# 검색 질의:  아이폰
#                 Title  ...                                        Description
# 0               아이폰12  ...  그냥 아이폰12와 아이폰12프로는 크기가 같나요? 친구에게 사주려고 하는데 잘 모르...
# 1            아이폰12 질문  ...  아이폰12랑 아이폰12 프로 차이가 뭔가요 아이폰12 질문 아이폰12랑 아이폰12 ...
# 2              아이폰 구매  ...  아이폰을 구매하려고 생각중인데요 아이폰 se2 랑 아이폰 12 프로, 둘 중에 뭘 ...
# 3              아이폰 13  ...  아이폰 13 vs 아이폰 13 pro 어떤게 더 예쁜것 같나요?? 아이폰 13 vs...
# 4    아이폰13미니vs아이폰12미니  ...  다음달에 휴대폰으로 바꾸려고 합니다 10월에 아이폰 13나오다고 해서 뭐로 바꾸면 ...
# ..                ...  ...                                                ...
# 995         아이폰 사러가는데  ...  다음주쯤에 아이폰을 사려하는데요.. 강변 테크노마트에서 사려고 하거든요? 아이폰 1...
# 996         아이폰12or13  ...  아이폰12pro를 사려고 하는데 내년에 나올 아이폰13pro를 기다려야하나 고민입니...
# 997             아이폰11  ...  ... 아이폰11으로 바꿀려고하는데요 친구들 말을 들어보니까 아이폰11 재고가 없다...
# 998       아이폰 계정관련..!  ...  ... 제가 삼성폰을 쓰다가 이제 아이폰으로 넘어가려합니다!... (+갤럭시든 아이...
# 999      아이폰을 살려고 합니다  ...  아이폰을 사고 싶은데 아이폰11이 좋을까요 아니면 아이폰12미니가 좋을까요? 이유까...
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 블로그 API

# %%
query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display =100
start = 1
end = 1000
sort = "sim"

blog_df = pd.DataFrame(columns=("Title", "Link", "Description", "Blogger Name","Bloger Link","Post Date"))

for start_index in range(start, end, display):
                            
    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
           + "&display=" + str(display) \
           + "&start=" + str(start_index) \
           + "&sort=" + sort
                  
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode() 
    if(rescode==200): #200은 성공한것
        response_body = response.read()
        response_dict =json.loads(response_body.decode('utf-8'))      
        #json title link description parse
        items = response_dict['items']
        for item_index in range(0, len(items)):
          remove_tag = re.compile('<.*?>')
          title =re.sub(remove_tag, '', items[item_index]['title'])
          link = items[item_index]['link']
          description = re.sub(remove_tag, '', items[item_index]['description'])
          blogger_name = items[item_index]['bloggername']
          blogger_link = items[item_index]['bloggerlink'] 
          post_date = items[item_index]['postdate']  
          blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link, post_date]
          idx += 1
    else:
        print("Error Code:" + rescode)
blog_df
# Out:
# 검색 질의:  클미핑크
#                                               Title  ... Post Date
# 0    샤넬 오픈런 성공: 클미 베이비핑크(NA116) 구매 &amp; 언박싱 후기...   ...  20210224
# 1               신세계 센텀시티점 샤넬 오픈런 한방에 클래식 미디움 클미...   ...  20210621
# 2            샤넬가방 종류 애칭 알아보아요~ㅎ 클스, 클미, 보이백,19백...   ...  20210627
# 3       (6편) - YOLO 안 해요, Flex 합니다. 샤넬 오픈런으로 클미 성공.  ...  20210902
# 4                  파우더핑크(엔젤팩토리)/미차✔지존 지존버전 베이지클미/미차  ...  20210522
# ..                                              ...  ...       ...
# 959           만능크림 영양크림 추천 : 코니샤 오아시스 블러썸 세라마이드...   ...  20210913
# 960                                              냠냠  ...  20200707
# 961                   샤넬 클래식모델 살펴보기 (뉴미니 쁘띠삭 스몰 미듐)  ...  20201113
# 962                응어...으...응어....슈..슈퍼억....ㅜㅜㅜㅜㅜㅜㅜ  ...  20100108
# 963                      [스와니코코]달팽이허브썬크림/썬블럭크림 사용후기  ...  20100423
#
# [964 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 API

# %%
query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display =100
start = 1
end = 1000
sort = "sim"

book_df = pd.DataFrame(columns=("Title", "Link", "Image","Author","Price","Discount",
                               "Publisher","ISBN","Description","Publication date"))

for start_index in range(start, end, display):
                            
    url = "https://openapi.naver.com/v1/search/book?query=" + query \
           + "&display=" + str(display) \
           + "&start=" + str(start_index) \
           + "&sort=" + sort
                  
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode() 
    if(rescode==200): #200은 성공한것
        response_body = response.read()
        response_dict =json.loads(response_body.decode('utf-8'))      
        #json title link description parse
        items = response_dict['items']
        for item_index in range(0, len(items)):
          remove_tag = re.compile('<.*?>')
          title =re.sub(remove_tag, '', items[item_index]['title'])
          link = items[item_index]['link']
          image = items[item_index]['image']
          author = items[item_index]['author']
          price = items[item_index]['price']  
          discount = items[item_index]['discount']  
          publisher = items[item_index]['publisher']  
          isbn = items[item_index]['isbn']  
          description = re.sub(remove_tag, '', items[item_index]['description'])
          pubdate = items[item_index]['pubdate']
          book_df.loc[idx] = [title, link, image, author, price, discount, publisher, isbn,
                              description, pubdate]
          idx += 1
    else:
        print("Error Code:" + rescode)
book_df
# Out:
# 검색 질의:  파이참
#                                               Title  ... Publication date
# 0     파이썬에 참 좋은 PyCharm (나에게 가장 필요한 파이썬 개발 환경 구축하기)  ...         20191031
# 1               참 쉬운 떡 만들기 (누가 해도 참 맛있는 떡 & 한식 디저트)  ...         20160610
# 2        참 쉬운 에어프라이어 (요알못도 쉽게 만들 수 있는,상황별 106가지 요리)  ...         20190910
# 3                          참 쉬운 핑거푸드 (케이터링을 위한 첫걸음)  ...         20210129
# 4                                         참쉬운 떡 만들기  ...         20080520
# ..                                              ...  ...              ...
# 201                                       교육과정학의 이해  ...         20070910
# 202                     MorningCalm(모닝캄 2014년 11월호)  ...         20141024
# 203                                    차와 드라마 마주 앉다  ...         20071225
# 204                                    대통령을 키운 어머니들  ...         20010825
# 205  iPhone Advanced Projects + 하이브리드 아이폰 애플리케이션 개발  ...         20100525
#
# [206 rows x 10 columns]

# %% [markdown]
# ## 네이버 영화 API

# %%
query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display =100
start = 1
end = 1000
sort = "sim"

movie_df = pd.DataFrame(columns=("Title", "Link", "Image","Subtitle","pubDate","Director",
                               "actor", "userRating"))

for start_index in range(start, end, display):
                            
    url = "https://openapi.naver.com/v1/search/movie?query=" + query \
           + "&display=" + str(display) \
           + "&start=" + str(start_index) \
           + "&sort=" + sort
                  
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode() 
    if(rescode==200): #200은 성공한것
        response_body = response.read()
        response_dict =json.loads(response_body.decode('utf-8'))      
        #json title link description parse
        items = response_dict['items']
        for item_index in range(0, len(items)):
          remove_tag = re.compile('<.*?>')
          title =re.sub(remove_tag, '', items[item_index]['title'])
          link = items[item_index]['link']
          image = items[item_index]['image']
          subtitle = items[item_index]['subtitle']
          pub_date = items[item_index]['pubDate']  
          director = items[item_index]['director']  
          actor = items[item_index]['actor']  
          user_rating = items[item_index]['userRating']  
          
          movie_df.loc[idx] = [title, link, image, subtitle, pub_date, director, actor, user_rating]
          idx += 1
    else:
        print("Error Code:" + rescode)
movie_df
# Out:
# 검색 질의:  아이언맨
#                    Title  ... userRating
# 0        일론 머스크: 리얼 아이언맨  ...       5.32
# 1                   아이언맨  ...       4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...       9.00
# 3                 아이언맨 3  ...       8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...       3.28
# ..                   ...  ...        ...
# 125           인빈서블 아이언 맨  ...       7.24
# 126     특수공작원 아이언맨 - 시리즈  ...       7.63
# 127           특수공작원 아이언맨  ...       9.00
# 128                아이언 맨  ...       5.37
# 129                아이언 맨  ...       7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버쇼핑 API

# %%
query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display =100
start = 1
end = 1000
sort = "sim"

shop_df = pd.DataFrame(columns=("Title", "Link", "Image","Low Price","High Price","Mall Name",
                               "Product ID", "Product Type","Maker","Brand"))

for start_index in range(start, end, display):
                            
    url = "https://openapi.naver.com/v1/search/shop?query=" + query \
           + "&display=" + str(display) \
           + "&start=" + str(start_index) \
           + "&sort=" + sort
                  
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode() 
    if(rescode==200): #200은 성공한것
        response_body = response.read()
        response_dict =json.loads(response_body.decode('utf-8'))      
        #json title link description parse
        items = response_dict['items']
        for item_index in range(0, len(items)):
          remove_tag = re.compile('<.*?>')
          title =re.sub(remove_tag, '', items[item_index]['title'])
          link = items[item_index]['link']
          image = items[item_index]['image']
          low_price = items[item_index]['lprice']
          high_price = items[item_index]['hprice']  
          mall_name = items[item_index]['mallName']  
          product_id = items[item_index]['productId']  
          product_type = items[item_index]['productType']  
          maker = items[item_index]['maker']  
          brand = items[item_index]['brand']  
          shop_df.loc[idx] = [title, link, image, low_price, high_price, mall_name, product_id, product_type,
                             maker, brand]
          idx += 1
    else:
        print("Error Code:" + rescode)
shop_df
# Out:
# 검색 질의:  파이참
#                                                  Title  ...  Brand
# 0               아즈레 벨라 보석 그리스 알파벳 문자 파이 참 스털링 실버 - 미국제  ...
# 1    레드 에나멜 로즈 플라워 알파 파이 참 펜던트 그리스 사회 보석 대학 여학생 클럽 ...  ...
# 2                그리스어 글자 라인석 제타 파이 베타 참 팔찌, 여성 여학생 쥬얼리  ...
# 3    빛나는 라인 석 상감 에나멜 대학 그리스 문자 사회 델타 시그마 파이 리더십 재단 ...  ...
# 4    큐티 파이 하트 럭키 스타 롤리팝 참 펜던트 쥬얼리 만들기 팔찌 귀걸이 만들기 수지...  ...
# ..                                                 ...  ...    ...
# 507  무료배송-coms 아이피타임 N6 유무선공유기 안테나2 유선2포트--품질이 참 좋은...  ...
# 508    [인기]_고리자석 강력 대형 고리자석 40파이 42파이 48파이 Cham79855ea  ...
# 509  S.H.Figuarts 가면 라이더개 무가면 라이더참 월・진실 멜론 에너지 암의 전...  ...    반다이
# 510  □◎나이키(NIKE) women’s 스포츠 참(매력) T셔츠 CJ7915-610 레이디스  ...    나이키
# 511  [참좋아] ipTIME 아이피타임 N604 Black 11n 유무선 IP공유기 아이...  ...  아이피타임
#
# [512 rows x 10 columns]

# %% [markdown]
# ## 네이버 뉴스 API

# %%
query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display =100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns=("Title", "Original Link", "Link", "Description", "pubDate"))

for start_index in range(start, end, display):
                            
    url = "https://openapi.naver.com/v1/search/news?query=" + query \
           + "&display=" + str(display) \
           + "&start=" + str(start_index) \
           + "&sort=" + sort
                  
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode() 
    if(rescode==200): #200은 성공한것
        response_body = response.read()
        response_dict =json.loads(response_body.decode('utf-8'))      
        #json title link description parse
        items = response_dict['items']
        for item_index in range(0, len(items)):
          remove_tag = re.compile('<.*?>')
          title =re.sub(remove_tag, '', items[item_index]['title'])
          Original_link = items[item_index]['originallink']
          link = items[item_index]['link']
          description = re.sub(remove_tag, '', items[item_index]['description'])
          pub_date = items[item_index]['pubDate']
          news_df.loc[idx] = [title, Original_link, link, description, pub_date]
          idx += 1
    else:
        print("Error Code:" + rescode)
news_df
# Out:
# 검색 질의:  파이참
#                                                  Title  ...                          pubDate
# 0    &quot;파이시티·내곡동 거짓말&quot;… 경찰 서울시청 압수수색, 오세훈 겨냥...  ...  Tue, 31 Aug 2021 13:13:00 +0900
# 1    '전세계 이닝 1위' 데스파이네 &quot;220이닝 목표 하지만 KS가 더 중요&...  ...  Thu, 19 Aug 2021 05:20:00 +0900
# 2                          파이참(PyCharm), '애플 실리콘' 지원한다  ...  Wed, 06 Jan 2021 11:34:00 +0900
# 3                      구로의 단단한 시설안전… IoT로 노후건물 24시간 감시  ...  Mon, 13 Sep 2021 05:06:00 +0900
# 4                광주 동구, &quot;경로당 무료 와이파이 이용하세요!&quot;  ...  Wed, 21 Jul 2021 18:36:00 +0900
# ..                                                 ...  ...                              ...
# 995             태풍이 덮친 장바구니 물가…두달새 장보기 28.4만원→30.3만원으로  ...  Sun, 06 Sep 2020 18:03:00 +0900
# 996            [생생경제] 다주택자가 가진 50% 주택, 보유세 강화로 풀어나가야..  ...  Tue, 21 Jul 2020 16:33:00 +0900
# 997            [생생경제] 다주택자가 가진 50% 주택, 보유세 강화로 풀어나가야..  ...  Tue, 21 Jul 2020 17:00:00 +0900
# 998         성추행 당할 때도 &quot;감사합니다&quot;... 해병대의 반복된 비극  ...  Thu, 03 Sep 2020 08:18:00 +0900
# 999             [개발자 칼럼] 21세기 호모 루덴스를 위한 게이미피케이션 모듬 세트  ...  Wed, 02 Sep 2020 18:19:00 +0900
#
# [1000 rows x 5 columns]
